# %% [markdown]
# # Zadatak 1 - Obrada podataka kroz Pandas

# %% [markdown]
# a) Učitati datoteku izvještaj.csv kao Pandas DataFrame, te prikazati prvih 5 i posljednjih 10 unosa u istoj;

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('izvjestaj.csv')
data.head()
data.tail(10)
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 37  38  71-ST         10      /      /               /               /
# 38  39  54-ST         10      /      /               /               /
# 39  40  60-ST         10     10      /               /               /
# 40  41  48-ST         10      /      /               /               /
# 41  42  61-ST         10      /      /               /               /
# 42  43   1-ST         10      /      /               /               /
# 43  44  88-ST         10      /      /               /               /
# 44  45  75-ST         10      /      /            9.83            13.5
# 45  46  67-ST         10   16.5      /               /               /
# 46  47  81-ST         10   15.7   17.3               /               /
#
#     UKUPNO Ocjena
# 37   42.16      8
# 38   19.35      /
# 39   38.50      6
# 40   10.00      6
# 41   23.12      /
# 42   10.00      /
# 43   37.00      7
# 44   33.33      6
# 45   39.50      7
# 46   43.00      8

# %% [markdown]
# b) Ispisati samo podatke vezane za redovne parcijalne ispite (kolone Ispit1 i Ispit2 );

# %%
data[['Ispit1', 'Ispit2']]
# Out:
#    Ispit1 Ispit2
# 0     9.4    7.5
# 1     8.5      /
# 2      17      /
# 3     7.6    4.8
# 4    10.6   12.5
# 5       /      /
# 6       /   12.5
# 7       /      /
# 8       /      /
# 9       /      /
# 10      /      /
# 11     13    7.8
# 12   15.6    7.7
# 13      /      /
# 14      /      /
# 15   12.5    7.8
# 16      /      /
# 17      /      /
# 18      /      /
# 19      /      /
# 20     14    9.7
# 21   12.5      /
# 22   10.7      /
# 23   13.6   12.5
# 24   12.5    6.5
# 25      /      /
# 26   16.6    8.7
# 27      /      /
# 28   10.8   12.5
# 29      /   12.5
# 30      /      /
# 31      /      /
# 32    7.5    1.7
# 33     10    1.5
# 34      /      /
# 35   13.3     15
# 36      /      /
# 37      /      /
# 38      /      /
# 39     10      /
# 40      /      /
# 41      /      /
# 42      /      /
# 43      /      /
# 44      /      /
# 45   16.5      /
# 46   15.7   17.3

# %% [markdown]
# c) Ispisati sve studente koji su izgubili prisustvo;

# %%
data.loc[data['Prisustvo'] == 0]
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 3    4  79-ST          0    7.6    4.8               /               /
# 5    6  78-ST          0      /      /           13.08           12.83
# 8    9  83-ST          0      /      /               /               /
# 22  23  74-ST          0   10.7      /           14.58            11.7
# 28  29  95-ST          0   10.8   12.5            7.25               /
# 31  32  41-ST          0      /      /               /               /
# 32  33  17-ST          0    7.5    1.7            2.33               /
# 33  34  82-ST          0     10    1.5               /               /
# 34  35  15-ST          0      /      /               /               /
#
#     UKUPNO Ocjena
# 3    12.40      /
# 5    25.91      6
# 8     0.00      /
# 22   27.08      /
# 28   23.50      /
# 31    5.87      /
# 32    9.20      /
# 33   16.00      /
# 34    0.00      /

# %% [markdown]
# d) Ispisati indeks, ukupne bodove, i ocjenu, za sve studente koji su upisali ocjenu 8 ili više;

# %%
data.loc[data['Ocjena'] >= '8', ['Indeks', 'UKUPNO', 'Ocjena']]
# Out:
#    Indeks  UKUPNO Ocjena
# 2   69-ST   39.50      9
# 6   93-ST   35.17      8
# 7   68-ST   50.00      9
# 9   92-ST   42.06      9
# 10  65-ST   43.19      8
# 12  90-ST   39.90      8
# 13  97-ST   41.05      9
# 14  84-ST   43.56      9
# 16  91-ST   43.48      9
# 19  96-ST   41.40      8
# 20  66-ST   40.00      8
# 21  62-ST   42.00      8
# 25  80-ST   39.45      8
# 26  63-ST   46.60      8
# 35  64-ST   38.30      8
# 37  71-ST   42.16      8
# 46  81-ST   43.00      8

# %% [markdown]
# e) Sve nedostajuće vrijednosti (označene sa simbolom /) zamijeniti sa vrijednošću np.nan;

# %%
data.replace('/', np.nan, inplace=True)
data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.08           13.73
# 1    2  77-ST         10    8.5    NaN             NaN             NaN
# 2    3  69-ST         10     17    NaN             NaN             NaN
# 3    4  79-ST          0    7.6    4.8             NaN             NaN
# 4    5  89-ST         10   10.6   12.5           12.58             NaN
# 5    6  78-ST          0    NaN    NaN           13.08           12.83
# 6    7  93-ST         10    NaN   12.5           12.67             NaN
# 7    8  68-ST         10    NaN    NaN             NaN             NaN
# 8    9  83-ST          0    NaN    NaN             NaN             NaN
# 9   10  92-ST         10    NaN    NaN             NaN             NaN
# 10  11  65-ST         10    NaN    NaN             NaN             NaN
# 11  12  70-ST         10     13    7.8             NaN            16.3
# 12  13  90-ST         10   15.6    7.7             NaN            14.3
# 13  14  97-ST         10    NaN    NaN             NaN             NaN
# 14  15  84-ST         10    NaN    NaN             NaN             NaN
# 15  16  98-ST         10   12.5    7.8             NaN            9.53
# 16  17  91-ST         10    NaN    NaN             NaN             NaN
# 17  18  87-ST         10    NaN    NaN             NaN             NaN
# 18  19  76-ST         10    NaN    NaN             NaN             NaN
# 19  20  96-ST         10    NaN    NaN             NaN             NaN
# 20  21  66-ST         10     14    9.7             NaN              16
# 21  22  62-ST         10   12.5    NaN             NaN             NaN
# 22  23  74-ST          0   10.7    NaN           14.58            11.7
# 23  24  86-ST         10   13.6   12.5             NaN             NaN
# 24  25  73-ST         10   12.5    6.5             NaN           19.07
# 25  26  80-ST         10    NaN    NaN             NaN             NaN
# 26  27  63-ST         10   16.6    8.7             NaN              20
# 27  28  72-ST         10    NaN    NaN             NaN             NaN
# 28  29  95-ST          0   10.8   12.5            7.25             NaN
# 29  30  85-ST         10    NaN   12.5             NaN             NaN
# 30  31  99-ST         10    NaN    NaN           14.17             NaN
# 31  32  41-ST          0    NaN    NaN             NaN             NaN
# 32  33  17-ST          0    7.5    1.7            2.33             NaN
# 33  34  82-ST          0     10    1.5             NaN             NaN
# 34  35  15-ST          0    NaN    NaN             NaN             NaN
# 35  36  64-ST         10   13.3     15             NaN             NaN
# 36  37  44-ST         10    NaN    NaN               8           14.33
# 37  38  71-ST         10    NaN    NaN             NaN             NaN
# 38  39  54-ST         10    NaN    NaN             NaN             NaN
# 39  40  60-ST         10     10    NaN             NaN             NaN
# 40  41  48-ST         10    NaN    NaN             NaN             NaN
# 41  42  61-ST         10    NaN    NaN             NaN             NaN
# 42  43   1-ST         10    NaN    NaN             NaN             NaN
# 43  44  88-ST         10    NaN    NaN             NaN             NaN
# 44  45  75-ST         10    NaN    NaN            9.83            13.5
# 45  46  67-ST         10   16.5    NaN             NaN             NaN
# 46  47  81-ST         10   15.7   17.3             NaN             NaN
#
#     UKUPNO Ocjena
# 0    35.81      7
# 1    35.50      7
# 2    39.50      9
# 3    12.40    NaN
# 4    35.08      6
# 5    25.91      6
# 6    35.17      8
# 7    50.00      9
# 8     0.00    NaN
# 9    42.06      9
# 10   43.19      8
# 11   39.30      7
# 12   39.90      8
# 13   41.05      9
# 14   43.56      9
# 15   38.50    NaN
# 16   43.48      9
# 17   35.89      7
# 18   27.18    NaN
# 19   41.40      8
# 20   40.00      8
# 21   42.00      8
# 22   27.08    NaN
# 23   36.10      6
# 24   41.57      7
# 25   39.45      8
# 26   46.60      8
# 27   18.41    NaN
# 28   23.50    NaN
# 29   35.25      7
# 30   24.17    NaN
# 31    5.87    NaN
# 32    9.20    NaN
# 33   16.00    NaN
# 34    0.00    NaN
# 35   38.30      8
# 36   32.33    NaN
# 37   42.16      8
# 38   19.35    NaN
# 39   38.50      6
# 40   10.00      6
# 41   23.12    NaN
# 42   10.00    NaN
# 43   37.00      7
# 44   33.33      6
# 45   39.50      7
# 46   43.00      8

# %% [markdown]
# f) Iz skupa podataka odbaciti sve studente koji nemaju upisanu ocjenu;

# %%
data.dropna(subset=['Ocjena'], inplace=True)
data
# Out:
#     id Indeks  Prisustvo Ispit1 Ispit2 Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10    9.4    7.5           12.08           13.73
# 1    2  77-ST         10    8.5    NaN             NaN             NaN
# 2    3  69-ST         10     17    NaN             NaN             NaN
# 4    5  89-ST         10   10.6   12.5           12.58             NaN
# 5    6  78-ST          0    NaN    NaN           13.08           12.83
# 6    7  93-ST         10    NaN   12.5           12.67             NaN
# 7    8  68-ST         10    NaN    NaN             NaN             NaN
# 9   10  92-ST         10    NaN    NaN             NaN             NaN
# 10  11  65-ST         10    NaN    NaN             NaN             NaN
# 11  12  70-ST         10     13    7.8             NaN            16.3
# 12  13  90-ST         10   15.6    7.7             NaN            14.3
# 13  14  97-ST         10    NaN    NaN             NaN             NaN
# 14  15  84-ST         10    NaN    NaN             NaN             NaN
# 16  17  91-ST         10    NaN    NaN             NaN             NaN
# 17  18  87-ST         10    NaN    NaN             NaN             NaN
# 19  20  96-ST         10    NaN    NaN             NaN             NaN
# 20  21  66-ST         10     14    9.7             NaN              16
# 21  22  62-ST         10   12.5    NaN             NaN             NaN
# 23  24  86-ST         10   13.6   12.5             NaN             NaN
# 24  25  73-ST         10   12.5    6.5             NaN           19.07
# 25  26  80-ST         10    NaN    NaN             NaN             NaN
# 26  27  63-ST         10   16.6    8.7             NaN              20
# 29  30  85-ST         10    NaN   12.5             NaN             NaN
# 35  36  64-ST         10   13.3     15             NaN             NaN
# 37  38  71-ST         10    NaN    NaN             NaN             NaN
# 39  40  60-ST         10     10    NaN             NaN             NaN
# 40  41  48-ST         10    NaN    NaN             NaN             NaN
# 43  44  88-ST         10    NaN    NaN             NaN             NaN
# 44  45  75-ST         10    NaN    NaN            9.83            13.5
# 45  46  67-ST         10   16.5    NaN             NaN             NaN
# 46  47  81-ST         10   15.7   17.3             NaN             NaN
#
#     UKUPNO Ocjena
# 0    35.81      7
# 1    35.50      7
# 2    39.50      9
# 4    35.08      6
# 5    25.91      6
# 6    35.17      8
# 7    50.00      9
# 9    42.06      9
# 10   43.19      8
# 11   39.30      7
# 12   39.90      8
# 13   41.05      9
# 14   43.56      9
# 16   43.48      9
# 17   35.89      7
# 19   41.40      8
# 20   40.00      8
# 21   42.00      8
# 23   36.10      6
# 24   41.57      7
# 25   39.45      8
# 26   46.60      8
# 29   35.25      7
# 35   38.30      8
# 37   42.16      8
# 39   38.50      6
# 40   10.00      6
# 43   37.00      7
# 44   33.33      6
# 45   39.50      7
# 46   43.00      8

# %% [markdown]
# g) Kreirati novu kolonu Ispit1_final u koju ćete za svakog studenta upisati onaj rezultat ispita koji je bolji (na
# primjer, ako je student bolje uradio popravni ispit, onda tu pišete bodove sa popravnog, a u protivnom sa
# redovnog);**bold text**

# %%
data['Ispit1'] = data['Ispit1'].astype(float)
data['Ispit1_popravni'] = data['Ispit1_popravni'].astype(float)

data['Ispit1_final'] = np.where(data['Ispit1'] > data['Ispit1_popravni'], data['Ispit1'], data['Ispit1_popravni'])
data
# Out:
#     id Indeks  Prisustvo  Ispit1 Ispit2  Ispit1_popravni Ispit2_popravni  \
# 0    1  94-ST         10     9.4    7.5            12.08           13.73
# 1    2  77-ST         10     8.5    NaN              NaN             NaN
# 2    3  69-ST         10    17.0    NaN              NaN             NaN
# 4    5  89-ST         10    10.6   12.5            12.58             NaN
# 5    6  78-ST          0     NaN    NaN            13.08           12.83
# 6    7  93-ST         10     NaN   12.5            12.67             NaN
# 7    8  68-ST         10     NaN    NaN              NaN             NaN
# 9   10  92-ST         10     NaN    NaN              NaN             NaN
# 10  11  65-ST         10     NaN    NaN              NaN             NaN
# 11  12  70-ST         10    13.0    7.8              NaN            16.3
# 12  13  90-ST         10    15.6    7.7              NaN            14.3
# 13  14  97-ST         10     NaN    NaN              NaN             NaN
# 14  15  84-ST         10     NaN    NaN              NaN             NaN
# 16  17  91-ST         10     NaN    NaN              NaN             NaN
# 17  18  87-ST         10     NaN    NaN              NaN             NaN
# 19  20  96-ST         10     NaN    NaN              NaN             NaN
# 20  21  66-ST         10    14.0    9.7              NaN              16
# 21  22  62-ST         10    12.5    NaN              NaN             NaN
# 23  24  86-ST         10    13.6   12.5              NaN             NaN
# 24  25  73-ST         10    12.5    6.5              NaN           19.07
# 25  26  80-ST         10     NaN    NaN              NaN             NaN
# 26  27  63-ST         10    16.6    8.7              NaN              20
# 29  30  85-ST         10     NaN   12.5              NaN             NaN
# 35  36  64-ST         10    13.3     15              NaN             NaN
# 37  38  71-ST         10     NaN    NaN              NaN             NaN
# 39  40  60-ST         10    10.0    NaN              NaN             NaN
# 40  41  48-ST         10     NaN    NaN              NaN             NaN
# 43  44  88-ST         10     NaN    NaN              NaN             NaN
# 44  45  75-ST         10     NaN    NaN             9.83            13.5
# 45  46  67-ST         10    16.5    NaN              NaN             NaN
# 46  47  81-ST         10    15.7   17.3              NaN             NaN
#
#     UKUPNO Ocjena  Ispit1_final
# 0    35.81      7         12.08
# 1    35.50      7           NaN
# 2    39.50      9           NaN
# 4    35.08      6         12.58
# 5    25.91      6         13.08
# 6    35.17      8         12.67
# 7    50.00      9           NaN
# 9    42.06      9           NaN
# 10   43.19      8           NaN
# 11   39.30      7           NaN
# 12   39.90      8           NaN
# 13   41.05      9           NaN
# 14   43.56      9           NaN
# 16   43.48      9           NaN
# 17   35.89      7           NaN
# 19   41.40      8           NaN
# 20   40.00      8           NaN
# 21   42.00      8           NaN
# 23   36.10      6           NaN
# 24   41.57      7           NaN
# 25   39.45      8           NaN
# 26   46.60      8           NaN
# 29   35.25      7           NaN
# 35   38.30      8           NaN
# 37   42.16      8           NaN
# 39   38.50      6           NaN
# 40   10.00      6           NaN
# 43   37.00      7           NaN
# 44   33.33      6          9.83
# 45   39.50      7           NaN
# 46   43.00      8           NaN

# %% [markdown]
# h) Ponoviti postupak za Ispit2 ;

# %%
data['Ispit2'] = data['Ispit2'].astype(float)
data['Ispit2_popravni'] = data['Ispit2_popravni'].astype(float)

data['Ispit2_final'] = np.where(pd.notna(data['Ispit2']) & (data['Ispit2'] > data['Ispit2_popravni']), data['Ispit2'], data['Ispit2_popravni'])
data

# %% [markdown]
# i) Odbaciti četiri stare kolone za ispite;

# %%
data.drop(columns=['Ispit1_popravni', 'Ispit2_popravni', 'Ispit1', 'Ispit2'], inplace=True)
data

# %% [markdown]
# j) Skup podataka sačuvati kao CSV datoteku pod nazivom izvjestaj_modificirano.csv. Koristiti znak tačka-zarez
# kao separator;

# %%
data.to_csv('izvjestaj_modificirano.csv', sep=';')

# %% [markdown]
# k) Skup podataka sačuvati kao Pickle datoteku pod nazivom izvjestaj_modificirano_pickle.p.

# %%
data.to_pickle('izvjestaj_modificirano_pickle.p')

# %% [markdown]
# # Zadatak 2 - Normalizacija podataka pomoću Sklearn

# %% [markdown]
# a) Učitati datoteku izvjestaj.csv kao Pandas DataFrame

# %%
data = pd.read_csv('izvjestaj.csv')
data.replace("/",np.nan, inplace=True)

# %% [markdown]
# b) Za kolone koje predstavljaju redovne ispite, izvršiti zamjenu nedostajućih vrijednosti strategijom median

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy='median')
data.loc[:, 'Ispit1'] = si.fit_transform(data.loc[:, 'Ispit1'].values.reshape(-1,1))
data.loc[:, 'Ispit2'] = si.fit_transform(data.loc[:, 'Ispit2'].values.reshape(-1,1))
data

# %% [markdown]
# c) Za kolone koje predstavljaju ispite, izvršiti zamjenu nedostajućih vrijednosti pomoću strategije mean

# %%
si = SimpleImputer(strategy='mean')
data.loc[:, 'Ispit1_popravni'] = si.fit_transform(data.loc[:, 'Ispit1_popravni'].values.reshape(-1,1))
data.loc[:, 'Ispit2_popravni'] = si.fit_transform(data.loc[:, 'Ispit2_popravni'].values.reshape(-1,1))
data

# %% [markdown]
# d) Izvršiti Z-score normalizaciju vrijednosti za redovne parcijalne ispite

# %%
from sklearn.preprocessing import scale
data['Ispit1'] = scale(data['Ispit1'])
data['Ispit2'] = scale(data['Ispit2'])
data

# %% [markdown]
# e) Izvršiti MinMax normalizaciju vrijednosti za popravne parcijalne ispite

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
data['Ispit1_popravni'] = mm.fit_transform(data['Ispit1_popravni'].values.reshape(-1,1))
data['Ispit2_popravni'] = mm.fit_transform(data['Ispit2_popravni'].values.reshape(-1,1))
data

# %% [markdown]
# f) Sve ostale nedostajuće vrijednosti u skupu podataka zamijeniti sa nulama

# %%
data.replace(np.nan,0,inplace=True)
data

# %% [markdown]
# g) Izdvojiti kolonu Ocjena u posebnu varijablu, na način da sada u originalnom skupu podataka ta kolona više ne postoji

# %%
x = data["Ocjena"]
data.drop(columns=['Ocjena'], inplace=True)
data

# %% [markdown]
# h) Konvertovati obje varijable (originalni skup podataka bez kolone Ocjena, kao i posebnu kolonu Ocjena) u NumPy nizove

# %%
varijabla = np.array(x)
print(varijabla)
tabela = data.to_numpy()
print(tabela)

# %% [markdown]
# i) Ukoliko pretpostavimo da NumPy niz sa ocjenama predstavlja labele, a niz sa ostalim kolonama atribute(značajke), izvršiti podjelu na trening i testni skup podataka, pri čemu za testni skup treba uzeti 20% podataka

# %%
from sklearn.model_selection import train_test_split

X = tabela
Y = varijabla

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.20)
